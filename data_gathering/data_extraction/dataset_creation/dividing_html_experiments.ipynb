# %%
import re
import json

from bs4 import BeautifulSoup, NavigableString, Tag
from transformers import T5TokenizerFast
from markdownify import ATX, BACKSLASH

from data_gathering.data_extraction.tree_modification import simplify_body, textify_simplified_head
from data_gathering.data_extraction.html2markdown import create_md
from data_gathering.data_extraction.utils import get_binary_dicts_templates

# %%
tokenizer = T5TokenizerFast.from_pretrained("google/flan-t5-base")

# %%
url_regex = r"(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'\".,<>?«»“”‘’]))"

# %%
with open("../dataset_creation_config.json", "r") as file:
    config = json.load(file)

tags_to_include = set(config["tags"])
text_formatting_tags = set(config["text_formatting_tags"])
meta_values = config["meta_values"]
abbreviations = config["abbreviations"]
(
    available_tags_binary_dict,
    available_attributes_values_binary_dict,
) = get_binary_dicts_templates(config)

# %%
md = create_md(heading_style=ATX, newline_style=BACKSLASH)

# %%
prompt = "Extract all information about the product from this text from a web store. Extract product title, brand, current price, old price, specifications (including material and dimensions), description, all sizes, all colors, all variants, categories, breadcrumbs, ratings (including number per each rating), opinions, number of available items (for each size) if provided else return null. Also extract similar products, products I may also like, related products, recommended for me but only return product name, brand and price. Categorize the product yourself (provide one general and one specific category). For each opinion return only the opinion text itself. If there's no information return: null. Answer should be in a proper JSON format. The text:"

# %%
input = tokenizer(prompt)

# %%
prompt_desc_size = len(input.input_ids)

# %%
model_max_input_size = 2048

# %% [markdown]
# ## Max input length to be added
#
# model_max_input_size = 2048

# %%
def get_max_input_size(model_max_input_size: int, prompt_desc_size: int, header_md: str, tokenizer: T5TokenizerFast) -> int:
    return model_max_input_size - prompt_desc_size - len(tokenizer(header_md).input_ids)

# %%
def join_tags(elems, tag_name):
    html = ""

    for partial_html, _ in elems:
        html += partial_html

    html = f"<{tag_name}>{html}</{tag_name}>"
    print("="*20)
    print("html", html[:100])
    print("="*20)
    # soup = BeautifulSoup(html, "html.parser")

    # if tag_name == "body":
    #     return str(soup.body)
    # else:
    # html = soup.body.contents[0]
    return html

def join_as_many_tags_as_possible(parts, max_size: int, tag_name="body"):
    final = []
    temp = []
    curr_len = 0

    # i = 0
    # while i < len(parts):
    #     if temp:
    #         if curr_len + parts[i][1] <= max_size:
    #             temp.append(parts[i])
    #             curr_len += parts[i][1]
    #         else:
    #             final.append((join_tags(temp, tag_name), curr_len))
    #             temp = [parts[i]]
    #             curr_len = parts[i][1]
    #     else:
    #         temp = [parts[i]]
    #         curr_len = parts[i][1]
    #
    #     i += 1

    for part, size in parts:
        if temp:
            if curr_len + size <= max_size:
                temp.append((part, size))
                curr_len += size
            else:
                final.append((join_tags(temp, tag_name), curr_len))
                temp = [(part, size)]
                curr_len = size
        else:
            temp = [(part, size)]
            curr_len = size

    if temp:
        final.append((join_tags(temp, tag_name), curr_len))

    return final

def divide_html_version(soup, transform_html_func, max_size):
    text = tokenizer(transform_html_func(soup)).input_ids
    size = len(text)
    print("size", size)

    if size <= max_size:
        return str(soup), size

    # if len(soup.contents) <= 1 and isinstance(soup.contents[0], NavigableString):
    #     return []

    # for elem in soup.contents:
    #     if not isinstance(elem, Tag) and len(soup.contents) > 1:
    #         return None

    print()
    print("="*30)
    print(str(soup)[:100])
    print("="*30)
    print()

    parts = []

    for elem in soup.contents:
        print("+"*20)
        print(str(elem)[:100])
        print("+"*20)
        res = divide_html_version(soup=elem, transform_html_func=transform_html_func, max_size=max_size) if isinstance(elem, Tag) else (str(elem), len(tokenizer(str(elem)).input_ids))

        if res is None:
            return None
        elif isinstance(res, list):
            print("res len", len(res))
            parts += res
        else:
            print("res len", 1)
            parts.append(res)

    return join_as_many_tags_as_possible(parts=parts, max_size=max_size, tag_name=soup.name)

# %%
with open("../stats/original_pages_html/8000_tokens/english_craftonlineusa_626.html", "r") as f:
    html = f.read()

soup = BeautifulSoup(html, "html.parser")

# %%
simplified_soup_head_text = textify_simplified_head(soup=soup.head, meta_acceptable_values=meta_values)
simplified_soup_body = simplify_body(
    soup=soup.body,
    text_formatting_tags=text_formatting_tags,
    tags_to_include=tags_to_include,
)
simplified_body_text = md(simplified_soup_body)

full_page_text = f"{simplified_soup_head_text}\n{simplified_body_text}"
full_page_text = re.sub(url_regex, "", full_page_text)

# %%
full_input = tokenizer(full_page_text).input_ids

# %%
len(full_input)
# Out:
# 8268

# %%
with open("simplified.html", "w") as f:
    f.write(simplified_soup_body.prettify())

with open("simplified_head_txt.html", "w") as f:
    f.write(simplified_soup_head_text)

# %%
max_input_size = get_max_input_size(model_max_input_size, prompt_desc_size, simplified_soup_head_text, tokenizer)

# %%
max_input_size
# Out:
# 1617

# %%
res = divide_html_version(simplified_soup_body, transform_html_func=md, max_size=max_input_size)
# Out:
# size 8097
#
# ==============================
# <body class="templateProduct"><div class="boxes-wrapper"><div id="page-body"><div id="body-content">
# ==============================
#
# ++++++++++++++++++++
# <div class="boxes-wrapper"><div id="page-body"><div id="body-content"><div class="container"><div id
# ++++++++++++++++++++
# size 8097
#
# ==============================
# <div class="boxes-wrapper"><div id="page-body"><div id="body-content"><div class="container"><div id
# ==============================
#
# ++++++++++++++++++++
# <div id="page-body"><div id="body-content"><div class="container"><div id="main-content"><div class=
# ++++++++++++++++++++
# size 8077
#
# ==============================
# <div id="page-body"><div id="body-content"><div class="container"><div id="main-content"><div class=
# ==============================
#
# ++++++++++++++++++++
# <div id="body-content"><div class="container"><div id="main-content"><div class="main-content"><div
# ++++++++++++++++++++
# size 8077
#
# ==============================
# <div id="body-content"><div class="container"><div id="main-content"><div class="main-content"><div
# ==============================
#
# ++++++++++++++++++++
# <div class="container"><div id="main-content"><div class="main-content"><div itemscope="" itemtype="
# ++++++++++++++++++++
# size 8077
#
# ==============================
# <div class="container"><div id="main-content"><div class="main-content"><div itemscope="" itemtype="
# ==============================
#
# ++++++++++++++++++++
# <div id="main-content"><div class="main-content"><div itemscope="" itemtype="http://schema.org/Produ
# ++++++++++++++++++++
# size 8077
#
# ==============================
# <div id="main-content"><div class="main-content"><div itemscope="" itemtype="http://schema.org/Produ
# ==============================
#
# ++++++++++++++++++++
# <div class="main-content"><div itemscope="" itemtype="http://schema.org/Product"><span class="hide"
# ++++++++++++++++++++
# size 8077
#
# ==============================
# <div class="main-content"><div itemscope="" itemtype="http://schema.org/Product"><span class="hide"
# ==============================
#
# ++++++++++++++++++++
# <div itemscope="" itemtype="http://schema.org/Product"><span class="hide" itemprop="name"> Reminisce
# ++++++++++++++++++++
# size 8077
#
# ==============================
# <div itemscope="" itemtype="http://schema.org/Product"><span class="hide" itemprop="name"> Reminisce
# ==============================
#
# ++++++++++++++++++++
# <span class="hide" itemprop="name"> Reminisce Collection Kit 12X12 Farmers Market </span>
# ++++++++++++++++++++
# size 13
# res len 1
# ++++++++++++++++++++
# <div class="row"><div class="col-xs-12 col-sm-12 col-md-12"><div class="page-product product-single"
# ++++++++++++++++++++
# size 8066
#
# ==============================
# <div class="row"><div class="col-xs-12 col-sm-12 col-md-12"><div class="page-product product-single"
# ==============================
#
# ++++++++++++++++++++
# <div class="col-xs-12 col-sm-12 col-md-12"><div class="page-product product-single" id="col-main"><d
# ++++++++++++++++++++
# size 8066
#
# ==============================
# <div class="col-xs-12 col-sm-12 col-md-12"><div class="page-product product-single" id="col-main"><d
# ==============================
#
# ++++++++++++++++++++
# <div class="page-product product-single" id="col-main"><div class="product"><div class="row"><div cl
# ++++++++++++++++++++
# size 8066
#
# ==============================
# <div class="page-product product-single" id="col-main"><div class="product"><div class="row"><div cl
# ==============================
#
# ++++++++++++++++++++
# <div class="product"><div class="row"><div class="col-sm-12 col-md-5 product-image" id="product-imag
# ++++++++++++++++++++
# size 91
# res len 1
# ++++++++++++++++++++
# <div class="product-simple-tab"><div role="tabpanel"><div class="tab-content"><div class="tab-pane a
# ++++++++++++++++++++
# size 13
# res len 1
# ++++++++++++++++++++
# <div class="home-carousel" id="related_item"><h4> Related Products </h4><div class="related-items"><
# ++++++++++++++++++++
# size 7966
#
# ==============================
# <div class="home-carousel" id="related_item"><h4> Related Products </h4><div class="related-items"><
# ==============================
#
# ++++++++++++++++++++
# <h4> Related Products </h4>
# ++++++++++++++++++++
# size 4
# res len 1
# ++++++++++++++++++++
# <div class="related-items"><div class="product-wrapper"><div class="product-head"><div class="produc
# ++++++++++++++++++++
# size 7961
#
# ==============================
# <div class="related-items"><div class="product-wrapper"><div class="product-head"><div class="produc
# ==============================
#
# ++++++++++++++++++++
# <div class="product-wrapper"><div class="product-head"><div class="product-image"><div class="featur
# ++++++++++++++++++++
# size 958
# res len 1
# ++++++++++++++++++++
# <div class="product-wrapper"><div class="product-head"><div class="product-image"><div class="featur
# ++++++++++++++++++++
# size 1139
# res len 1
# ++++++++++++++++++++
# <div class="product-wrapper"><div class="product-head"><div class="product-image"><div class="featur
# ++++++++++++++++++++
# size 2714
#
# ==============================
# <div class="product-wrapper"><div class="product-head"><div class="product-image"><div class="featur
# ==============================
#
# ++++++++++++++++++++
# <div class="product-head"><div class="product-image"><div class="featured-img switch"><span class="p
# ++++++++++++++++++++
# size 2663
#
# ==============================
# <div class="product-head"><div class="product-image"><div class="featured-img switch"><span class="p
# ==============================
#
# ++++++++++++++++++++
# <div class="product-image"><div class="featured-img switch"><span class="product-label"><span class=
# ++++++++++++++++++++
# size 2663
#
# ==============================
# <div class="product-image"><div class="featured-img switch"><span class="product-label"><span class=
# ==============================
#
# ++++++++++++++++++++
# <div class="featured-img switch"><span class="product-label"><span class="label-sale"><span class="s
# ++++++++++++++++++++
# size 5
# res len 1
# ++++++++++++++++++++
# <div class="product-button"><div class="quick_shop quick-shop-button hidden-sm hidden-xs" data-handl
# ++++++++++++++++++++
# size 2660
#
# ==============================
# <div class="product-button"><div class="quick_shop quick-shop-button hidden-sm hidden-xs" data-handl
# ==============================
#
# ++++++++++++++++++++
# <div class="quick_shop quick-shop-button hidden-sm hidden-xs" data-handle="universal-crafts-30ml-cle
# ++++++++++++++++++++
# size 2660
#
# ==============================
# <div class="quick_shop quick-shop-button hidden-sm hidden-xs" data-handle="universal-crafts-30ml-cle
# ==============================
#
# ++++++++++++++++++++
# <span class="json hide"> {"id":2459828551761,"title":"Solu Crafts - Glitter Mister","handle":"univer
# ++++++++++++++++++++
# size 2660
#
# ==============================
# <span class="json hide"> {"id":2459828551761,"title":"Solu Crafts - Glitter Mister","handle":"univer
# ==============================
#
# ++++++++++++++++++++
#  {"id":2459828551761,"title":"Solu Crafts - Glitter Mister","handle":"universal-crafts-30ml-clear-po
# ++++++++++++++++++++
# res len 1
# ====================
# html <span> {"id":2459828551761,"title":"Solu Crafts - Glitter Mister","handle":"universal-crafts-30ml-cl
# ====================
# res len 1
# ====================
# html <div><span> {"id":2459828551761,"title":"Solu Crafts - Glitter Mister","handle":"universal-crafts-30
# ====================
# res len 1
# ====================
# html <div><div><span> {"id":2459828551761,"title":"Solu Crafts - Glitter Mister","handle":"universal-craf
# ====================
# res len 1
# ====================
# html <div><div class="featured-img switch"><span class="product-label"><span class="label-sale"><span cla
# ====================
# ====================
# html <div><div><div><span> {"id":2459828551761,"title":"Solu Crafts - Glitter Mister","handle":"universal
# ====================
# res len 2
# ====================
# html <div><div><div class="featured-img switch"><span class="product-label"><span class="label-sale"><spa
# ====================
# ====================
# html <div><div><div><div><span> {"id":2459828551761,"title":"Solu Crafts - Glitter Mister","handle":"univ
# ====================
# res len 2
# ++++++++++++++++++++
# <div class="product-content" data-href="/collections/15off/products/universal-crafts-30ml-clear-powd
# ++++++++++++++++++++
# size 53
# res len 1
# ====================
# html <div><div><div><div class="featured-img switch"><span class="product-label"><span class="label-sale"
# ====================
# ====================
# html <div><div><div><div><div><span> {"id":2459828551761,"title":"Solu Crafts - Glitter Mister","handle":
# ====================
# ====================
# html <div><div class="product-content" data-href="/collections/15off/products/universal-crafts-30ml-clear
# ====================
# res len 3
# ++++++++++++++++++++
# <div class="product-wrapper"><div class="product-head"><div class="product-image"><div class="featur
# ++++++++++++++++++++
# size 1780
#
# ==============================
# <div class="product-wrapper"><div class="product-head"><div class="product-image"><div class="featur
# ==============================
#
# ++++++++++++++++++++
# <div class="product-head"><div class="product-image"><div class="featured-img switch"><span class="p
# ++++++++++++++++++++
# size 1738
#
# ==============================
# <div class="product-head"><div class="product-image"><div class="featured-img switch"><span class="p
# ==============================
#
# ++++++++++++++++++++
# <div class="product-image"><div class="featured-img switch"><span class="product-label"><span class=
# ++++++++++++++++++++
# size 1738
#
# ==============================
# <div class="product-image"><div class="featured-img switch"><span class="product-label"><span class=
# ==============================
#
# ++++++++++++++++++++
# <div class="featured-img switch"><span class="product-label"><span class="label-sale"><span class="s
# ++++++++++++++++++++
# size 5
# res len 1
# ++++++++++++++++++++
# <div class="product-button"><div class="quick_shop quick-shop-button hidden-sm hidden-xs" data-handl
# ++++++++++++++++++++
# size 1735
#
# ==============================
# <div class="product-button"><div class="quick_shop quick-shop-button hidden-sm hidden-xs" data-handl
# ==============================
#
# ++++++++++++++++++++
# <div class="quick_shop quick-shop-button hidden-sm hidden-xs" data-handle="universal-crafts-ultimate
# ++++++++++++++++++++
# size 1735
#
# ==============================
# <div class="quick_shop quick-shop-button hidden-sm hidden-xs" data-handle="universal-crafts-ultimate
# ==============================
#
# ++++++++++++++++++++
# <span class="json hide"> {"id":3188921860177,"title":"Universal Crafts - Ultimate Blending Brush Set
# ++++++++++++++++++++
# size 1735
#
# ==============================
# <span class="json hide"> {"id":3188921860177,"title":"Universal Crafts - Ultimate Blending Brush Set
# ==============================
#
# ++++++++++++++++++++
#  {"id":3188921860177,"title":"Universal Crafts - Ultimate Blending Brush Set","handle":"universal-cr
# ++++++++++++++++++++
# res len 1
# ====================
# html <span> {"id":3188921860177,"title":"Universal Crafts - Ultimate Blending Brush Set","handle":"univer
# ====================
# res len 1
# ====================
# html <div><span> {"id":3188921860177,"title":"Universal Crafts - Ultimate Blending Brush Set","handle":"u
# ====================
# res len 1
# ====================
# html <div><div><span> {"id":3188921860177,"title":"Universal Crafts - Ultimate Blending Brush Set","handl
# ====================
# res len 1
# ====================
# html <div><div class="featured-img switch"><span class="product-label"><span class="label-sale"><span cla
# ====================
# ====================
# html <div><div><div><span> {"id":3188921860177,"title":"Universal Crafts - Ultimate Blending Brush Set","
# ====================
# res len 2
# ====================
# html <div><div><div class="featured-img switch"><span class="product-label"><span class="label-sale"><spa
# ====================
# ====================
# html <div><div><div><div><span> {"id":3188921860177,"title":"Universal Crafts - Ultimate Blending Brush S
# ====================
# res len 2
# ++++++++++++++++++++
# <div class="product-content" data-href="/collections/15off/products/universal-crafts-ultimate-blendi
# ++++++++++++++++++++
# size 44
# res len 1
# ====================
# html <div><div><div><div class="featured-img switch"><span class="product-label"><span class="label-sale"
# ====================
# ====================
# html <div><div><div><div><div><span> {"id":3188921860177,"title":"Universal Crafts - Ultimate Blending Br
# ====================
# ====================
# html <div><div class="product-content" data-href="/collections/15off/products/universal-crafts-ultimate-b
# ====================
# res len 3
# ++++++++++++++++++++
# <div class="product-wrapper"><div class="product-head"><div class="product-image"><div class="featur
# ++++++++++++++++++++
# size 1378
# res len 1
# ====================
# html <div><div class="product-wrapper"><div class="product-head"><div class="product-image"><div class="f
# ====================
# ====================
# html <div><div class="product-wrapper"><div class="product-head"><div class="product-image"><div class="f
# ====================
# ====================
# html <div><div><div><div><div><div><span> {"id":2459828551761,"title":"Solu Crafts - Glitter Mister","han
# ====================
# ====================
# html <div><div><div class="product-content" data-href="/collections/15off/products/universal-crafts-30ml-
# ====================
# ====================
# html <div><div><div><div><div><div><span> {"id":3188921860177,"title":"Universal Crafts - Ultimate Blendi
# ====================
# ====================
# html <div><div><div class="product-content" data-href="/collections/15off/products/universal-crafts-ultim
# ====================
# res len 6
# ====================
# html <div><h4> Related Products </h4><div><div class="product-wrapper"><div class="product-head"><div cla
# ====================
# ====================
# html <div><div><div class="product-wrapper"><div class="product-head"><div class="product-image"><div cla
# ====================
# ====================
# html <div><div><div><div><div><div><div><span> {"id":2459828551761,"title":"Solu Crafts - Glitter Mister"
# ====================
# ====================
# html <div><div><div><div class="product-content" data-href="/collections/15off/products/universal-crafts-
# ====================
# ====================
# html <div><div><div><div><div><div><div><span> {"id":3188921860177,"title":"Universal Crafts - Ultimate B
# ====================
# ====================
# html <div><div><div><div class="product-content" data-href="/collections/15off/products/universal-crafts-
# ====================
# res len 6
# ====================
# html <div><div class="product"><div class="row"><div class="col-sm-12 col-md-5 product-image" id="product
# ====================
# ====================
# html <div><div><div><div class="product-wrapper"><div class="product-head"><div class="product-image"><di
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><span> {"id":2459828551761,"title":"Solu Crafts - Glitter Mi
# ====================
# ====================
# html <div><div><div><div><div class="product-content" data-href="/collections/15off/products/universal-cr
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><span> {"id":3188921860177,"title":"Universal Crafts - Ultim
# ====================
# ====================
# html <div><div><div><div><div class="product-content" data-href="/collections/15off/products/universal-cr
# ====================
# res len 6
# ====================
# html <div><div><div class="product"><div class="row"><div class="col-sm-12 col-md-5 product-image" id="pr
# ====================
# ====================
# html <div><div><div><div><div class="product-wrapper"><div class="product-head"><div class="product-image
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><span> {"id":2459828551761,"title":"Solu Crafts - Glitt
# ====================
# ====================
# html <div><div><div><div><div><div class="product-content" data-href="/collections/15off/products/univers
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><span> {"id":3188921860177,"title":"Universal Crafts -
# ====================
# ====================
# html <div><div><div><div><div><div class="product-content" data-href="/collections/15off/products/univers
# ====================
# res len 6
# ====================
# html <div><div><div><div class="product"><div class="row"><div class="col-sm-12 col-md-5 product-image" i
# ====================
# ====================
# html <div><div><div><div><div><div class="product-wrapper"><div class="product-head"><div class="product-
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><span> {"id":2459828551761,"title":"Solu Crafts -
# ====================
# ====================
# html <div><div><div><div><div><div><div class="product-content" data-href="/collections/15off/products/un
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><span> {"id":3188921860177,"title":"Universal Craf
# ====================
# ====================
# html <div><div><div><div><div><div><div class="product-content" data-href="/collections/15off/products/un
# ====================
# res len 6
# ====================
# html <div><span class="hide" itemprop="name"> Reminisce Collection Kit 12X12 Farmers Market </span><div><
# ====================
# ====================
# html <div><div><div><div><div><div><div class="product-wrapper"><div class="product-head"><div class="pro
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><span> {"id":2459828551761,"title":"Solu Craf
# ====================
# ====================
# html <div><div><div><div><div><div><div><div class="product-content" data-href="/collections/15off/produc
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><span> {"id":3188921860177,"title":"Universal
# ====================
# ====================
# html <div><div><div><div><div><div><div><div class="product-content" data-href="/collections/15off/produc
# ====================
# res len 6
# ====================
# html <div><div><span class="hide" itemprop="name"> Reminisce Collection Kit 12X12 Farmers Market </span><
# ====================
# ====================
# html <div><div><div><div><div><div><div><div class="product-wrapper"><div class="product-head"><div class
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><span> {"id":2459828551761,"title":"Solu
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div class="product-content" data-href="/collections/15off/p
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><span> {"id":3188921860177,"title":"Univ
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div class="product-content" data-href="/collections/15off/p
# ====================
# res len 6
# ====================
# html <div><div><div><span class="hide" itemprop="name"> Reminisce Collection Kit 12X12 Farmers Market </s
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div class="product-wrapper"><div class="product-head"><div
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><div><span> {"id":2459828551761,"title":
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div class="product-content" data-href="/collections/15
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><div><span> {"id":3188921860177,"title":
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div class="product-content" data-href="/collections/15
# ====================
# res len 6
# ====================
# html <div><div><div><div><span class="hide" itemprop="name"> Reminisce Collection Kit 12X12 Farmers Marke
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div class="product-wrapper"><div class="product-head">
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><div><div><span> {"id":2459828551761,"ti
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div class="product-content" data-href="/collectio
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><div><div><span> {"id":3188921860177,"ti
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div class="product-content" data-href="/collectio
# ====================
# res len 6
# ====================
# html <div><div><div><div><div><span class="hide" itemprop="name"> Reminisce Collection Kit 12X12 Farmers
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div class="product-wrapper"><div class="product-h
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><span> {"id":245982855176
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div class="product-content" data-href="/coll
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><span> {"id":318892186017
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div class="product-content" data-href="/coll
# ====================
# res len 6
# ====================
# html <div><div><div><div><div><div><span class="hide" itemprop="name"> Reminisce Collection Kit 12X12 Far
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div class="product-wrapper"><div class="prod
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><span> {"id":2459828
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><div class="product-content" data-href="
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><span> {"id":3188921
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><div class="product-content" data-href="
# ====================
# res len 6
# ++++++++++++++++++++
# <div id="scroll-to-top" title="Back To Top"></div>
# ++++++++++++++++++++
# size 1
# res len 1
# ++++++++++++++++++++
# <div aria-hidden="true" class="modal fade" id="quick-shop-popup" role="dialog" tabindex="-1"><div cl
# ++++++++++++++++++++
# size 9
# res len 1
# ++++++++++++++++++++
# <div id="layer-addcart-modal" style="display: none; position: fixed; top: 0%; left: 0%; width: 100%;
# ++++++++++++++++++++
# size 15
# res len 1
# ====================
# html <div><div><div><div><div><div><div><span class="hide" itemprop="name"> Reminisce Collection Kit 12X1
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><div class="product-wrapper"><div class=
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><span> {"id":24
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><div><div class="product-content" data-h
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><span> {"id":31
# ====================
# ====================
# html <div><div><div><div><div><div><div><div><div><div><div><div><div><div class="product-content" data-h
# ====================
# res len 6
# ====================
# html <body><div><div><div><div><div><div><div><span class="hide" itemprop="name"> Reminisce Collection Ki
# ====================
# ====================
# html <body><div><div><div><div><div><div><div><div><div><div><div><div><div class="product-wrapper"><div
# ====================
# ====================
# html <body><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><span> {"
# ====================
# ====================
# html <body><div><div><div><div><div><div><div><div><div><div><div><div><div><div class="product-content"
# ====================
# ====================
# html <body><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><span> {"
# ====================
# ====================
# html <body><div><div><div><div><div><div><div><div><div><div><div><div><div><div class="product-content"
# ====================

# %%
if isinstance(res, list):
    for i, elem in enumerate(res):
        elem_soup = BeautifulSoup(elem[0], "html.parser")

        simplified_elem_text = md(elem_soup)

        full_page_text_curr = f"{simplified_soup_head_text}\n{simplified_elem_text}"
        full_page_text_curr = re.sub(url_regex, "", full_page_text_curr)

        input = tokenizer(full_page_text_curr).input_ids
        print(f"divided_{i} size", len(input) + prompt_desc_size)

        print(str(elem_soup)[:100])
        with open(f"divided_{i}.html", "w") as f:
            f.write(elem_soup.body.prettify())
else:
    with open("divided_0.html", "w") as f:
        f.write(BeautifulSoup(res[0], "html.parser").prettify())
# Out:
# divided_0 size 1391
# <body><div><div><div><div><div><div><div><span class="hide" itemprop="name"> Reminisce Collection Ki
# divided_1 size 1459
# <body><div><div><div><div><div><div><div><div><div><div><div><div><div class="product-wrapper"><div
# divided_2 size 2977
# <body><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><span> {"
# divided_3 size 373
# <body><div><div><div><div><div><div><div><div><div><div><div><div><div><div class="product-content"
# divided_4 size 2052
# <body><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><div><span> {"
# divided_5 size 1757
# <body><div><div><div><div><div><div><div><div><div><div><div><div><div><div class="product-content"
